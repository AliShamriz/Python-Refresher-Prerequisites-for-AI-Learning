# %%
import pandas as pd

# %%
df=pd.read_csv(
    'Data/btc-usd.csv',
    index_col='Date',
    parse_dates=['Date']
)
df.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2021-04-30  53568.664063  57900.718750  53129.601563  57750.175781
# 2021-05-01  57714.664063  58448.339844  57052.273438  57828.050781
# 2021-05-02  57825.863281  57902.593750  56141.906250  56631.078125
# 2021-05-03  56620.273438  58973.308594  56590.871094  57200.292969
# 2021-05-04  57214.179688  57214.179688  53191.425781  53333.539063
#
#                Adj Close       Volume
# Date
# 2021-04-30  57750.175781  52395931985
# 2021-05-01  57828.050781  42836427360
# 2021-05-02  56631.078125  38177405335
# 2021-05-03  57200.292969  51713139031
# 2021-05-04  53333.539063  68564706967

# %%
df['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df['Volume'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
delta = df['Close'] - df['Open']
delta.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(y='Open')
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(y=['High','Low'])
# Out:
# <Axes: xlabel='Date'>

# %%
movies = pd.read_csv('Data/movies.csv',index_col='name',parse_dates=['release_date'])
movies.head()
# Out:
#                                                rating      genre  year  \
# name
# The Shining                                         R      Drama  1980
# The Blue Lagoon                                     R  Adventure  1980
# Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# Airplane!                                          PG     Comedy  1980
# Caddyshack                                          R     Comedy  1980
#
#                                                  release_date release_country  \
# name
# The Shining                                     June 13, 1980   United States
# The Blue Lagoon                                  July 2, 1980   United States
# Star Wars: Episode V - The Empire Strikes Back  June 20, 1980   United States
# Airplane!                                        July 2, 1980   United States
# Caddyshack                                      July 25, 1980   United States
#
# ...

# %%
movies.sort_values(by='release_date',inplace=True)

# %%
movies.plot(y='score')
# Out:
# <Axes: xlabel='name'>

# %%
movies.plot(x='release_date',y='budget')
# Out:
# <Axes: xlabel='release_date'>

# %%
movies.plot(x='release_date',y='score')
# Out:
# <Axes: xlabel='release_date'>

# %%
movies.genre.value_counts()
# Out:
# genre
# Comedy       2245
# Action       1705
# Drama        1517
# Crime         550
# Biography     443
# Adventure     427
# Animation     338
# Horror        322
# Fantasy        44
# Mystery        20
# Thriller       16
# Family         11
# Sci-Fi         10
# Romance        10
# Western         3
# Musical         2
# Music           1
# Sport           1
# History         1
# Name: count, dtype: int64

# %%
movies.genre.value_counts().plot()
# Out:
# <Axes: xlabel='genre'>

# %%
movies.genre.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='genre'>

# %%
movies.genre.value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='genre'>

# %%
movies.rating.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='rating'>

# %%
movies.genre.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
movies.plot(x='release_date',y='budget',legend=False)
# Out:
# <Axes: xlabel='release_date'>

# %%
ROI = movies.gross / movies.budget -1

# %%
ROI.plot()
# Out:
# <Axes: xlabel='name'>

# %%
movies['ROI'] = ROI = movies.gross / movies.budget -1

# %%
movies.head()
# Out:
#                                 rating     genre  year release_date  \
# name
# Longshot                         TV-PG    Comedy  1981         1981
# Five Days One Summer                PG     Drama  1982         1982
# O.C. and Stiggs                      R    Comedy  1985         1985
# Taipei Story                 Not Rated     Drama  1985         1985
# The House on Carroll Street         PG  Thriller  1987         1987
#
#                             release_country  score   votes         director  \
# name
# Longshot                      United States    5.1   101.0  E.W. Swackhamer
# Five Days One Summer                  Japan    6.1  1000.0   Fred Zinnemann
# O.C. and Stiggs               United States    5.4  1200.0    Robert Altman
# Taipei Story                         Taiwan    7.7  2500.0      Edward Yang
# The House on Carroll Street   United States    6.1  2300.0      Peter Yates
#
#                                        writer            star        country  \
# ...

# %%
movies.plot(x='release_date',y='ROI')
# Out:
# <Axes: xlabel='release_date'>
