# %%
import pandas as pd

# %%
df = pd.read_csv('Data/Movies.csv',index_col='name')
df.head()
# Out:
#                                                rating      genre  year  \
# name
# The Shining                                         R      Drama  1980
# The Blue Lagoon                                     R  Adventure  1980
# Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# Airplane!                                          PG     Comedy  1980
# Caddyshack                                          R     Comedy  1980
#
#                                                  release_date release_country  \
# name
# The Shining                                     June 13, 1980   United States
# The Blue Lagoon                                  July 2, 1980   United States
# Star Wars: Episode V - The Empire Strikes Back  June 20, 1980   United States
# Airplane!                                        July 2, 1980   United States
# Caddyshack                                      July 25, 1980   United States
#
# ...

# %%
df.loc['A Beautiful Mind']
# Out:
# rating                          PG-13
# genre                       Biography
# year                             2001
# release_date          January 4, 2002
# release_country         United States
# score                             8.2
# votes                        871000.0
# director                   Ron Howard
# writer                 Akiva Goldsman
# star                    Russell Crowe
# country                 United States
# budget                     58000000.0
# gross                     316791257.0
# company            Universal Pictures
# runtime                         135.0
# Name: A Beautiful Mind, dtype: object

# %%
df.loc[['A Beautiful Mind','The Dark Knight']]
# Out:
#                  rating      genre  year     release_date release_country  \
# name
# A Beautiful Mind  PG-13  Biography  2001  January 4, 2002   United States
# The Dark Knight   PG-13     Action  2008    July 18, 2008   United States
#
#                   score      votes           director          writer  \
# name
# A Beautiful Mind    8.2   871000.0         Ron Howard  Akiva Goldsman
# The Dark Knight     9.0  2400000.0  Christopher Nolan  Jonathan Nolan
#
#                             star        country       budget         gross  \
# name
# A Beautiful Mind   Russell Crowe  United States   58000000.0  3.167913e+08
# The Dark Knight   Christian Bale  United States  185000000.0  1.005974e+09
#
#                              company  runtime
# name
# A Beautiful Mind  Universal Pictures    135.0
# The Dark Knight         Warner Bros.    152.0

# %%
df.head()
# Out:
#                                                rating      genre  year  \
# name
# The Shining                                         R      Drama  1980
# The Blue Lagoon                                     R  Adventure  1980
# Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# Airplane!                                          PG     Comedy  1980
# Caddyshack                                          R     Comedy  1980
#
#                                                  release_date release_country  \
# name
# The Shining                                     June 13, 1980   United States
# The Blue Lagoon                                  July 2, 1980   United States
# Star Wars: Episode V - The Empire Strikes Back  June 20, 1980   United States
# Airplane!                                        July 2, 1980   United States
# Caddyshack                                      July 25, 1980   United States
#
# ...

# %%
df.iloc[0]
# Out:
# rating                           R
# genre                        Drama
# year                          1980
# release_date         June 13, 1980
# release_country      United States
# score                          8.4
# votes                     927000.0
# director           Stanley Kubrick
# writer                Stephen King
# star                Jack Nicholson
# country             United Kingdom
# budget                  19000000.0
# gross                   46998772.0
# company               Warner Bros.
# runtime                      146.0
# Name: The Shining, dtype: object

# %%
df.iloc[0:5]
# Out:
#                                                rating      genre  year  \
# name
# The Shining                                         R      Drama  1980
# The Blue Lagoon                                     R  Adventure  1980
# Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# Airplane!                                          PG     Comedy  1980
# Caddyshack                                          R     Comedy  1980
#
#                                                  release_date release_country  \
# name
# The Shining                                     June 13, 1980   United States
# The Blue Lagoon                                  July 2, 1980   United States
# Star Wars: Episode V - The Empire Strikes Back  June 20, 1980   United States
# Airplane!                                        July 2, 1980   United States
# Caddyshack                                      July 25, 1980   United States
#
# ...

# %%
df.iloc[-1]
# Out:
# rating                          NaN
# genre                        Horror
# year                           2020
# release_date        August 19, 2020
# release_country       United States
# score                           5.7
# votes                           7.0
# director               Pereko Mosia
# writer                 Pereko Mosia
# star               Siyabonga Mabaso
# country                South Africa
# budget                          NaN
# gross                           NaN
# company                 PK 65 Films
# runtime                       102.0
# Name: Tee em el, dtype: object

# %%
df.iloc[-5:]
# Out:
#               rating   genre  year      release_date release_country  score  \
# name
# More to Life     NaN   Drama  2020  October 23, 2020   United States    3.1
# Dream Round      NaN  Comedy  2020  February 7, 2020   United States    4.7
# Saving Mbango    NaN   Drama  2020    April 27, 2020        Cameroon    5.7
# It's Just Us     NaN   Drama  2020   October 1, 2020   United States    NaN
# Tee em el        NaN  Horror  2020   August 19, 2020   United States    5.7
#
#                votes       director         writer              star  \
# name
# More to Life    18.0  Joseph Ebanks  Joseph Ebanks      Shannon Bond
# Dream Round     36.0   Dusty Dukatz    Lisa Huston  Michael Saquella
# Saving Mbango   29.0   Nkanya Nkwai   Lynno Lovert      Onyama Laura
# It's Just Us     NaN  James Randall  James Randall     Christina Roz
# Tee em el        7.0   Pereko Mosia   Pereko Mosia  Siyabonga Mabaso
#
#                      country   budget  gross                    company  \
# ...

# %%
df.sort_values(by='score')
# Out:
#                              rating   genre  year       release_date  \
# name
# The Hottie & the Nottie       PG-13  Comedy  2008  February 21, 2008
# Superbabies: Baby Geniuses 2     PG  Comedy  2004    August 27, 2004
# Disaster Movie                PG-13  Comedy  2008    August 29, 2008
# From Justin to Kelly             PG  Comedy  2003      June 20, 2003
# House of the Dead                 R  Action  2003   October 10, 2003
# ...                             ...     ...   ...                ...
# The Dark Knight               PG-13  Action  2008      July 18, 2008
# The Shawshank Redemption          R   Drama  1994   October 14, 1994
# Love by Drowning                  R   Drama  2020   November 6, 2020
# The Robinsons                   NaN  Action  2020  November 10, 2020
# It's Just Us                    NaN   Drama  2020    October 1, 2020
#
#                              release_country  score      votes  \
# name
# ...

# %%
df.iloc[0:5]
# Out:
#                                                rating      genre  year  \
# name
# The Shining                                         R      Drama  1980
# The Blue Lagoon                                     R  Adventure  1980
# Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# Airplane!                                          PG     Comedy  1980
# Caddyshack                                          R     Comedy  1980
#
#                                                  release_date release_country  \
# name
# The Shining                                     June 13, 1980   United States
# The Blue Lagoon                                  July 2, 1980   United States
# Star Wars: Episode V - The Empire Strikes Back  June 20, 1980   United States
# Airplane!                                        July 2, 1980   United States
# Caddyshack                                      July 25, 1980   United States
#
# ...

# %%
df.loc['The Shining':'The Dark Knight']
# Out:
#                                                rating      genre  year  \
# name
# The Shining                                         R      Drama  1980
# The Blue Lagoon                                     R  Adventure  1980
# Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# Airplane!                                          PG     Comedy  1980
# Caddyshack                                          R     Comedy  1980
# ...                                               ...        ...   ...
# Postal                                              R     Action  2007
# The Hunting Party                                   R  Adventure  2007
# Son of Rambow                                   PG-13     Action  2007
# Things We Lost in the Fire                          R      Drama  2007
# The Dark Knight                                 PG-13     Action  2008
#
#                                                       release_date  \
# name
# ...

# %%
# %%timeit
df.loc['The Shining','runtime']
# Out:
# 162 μs ± 1.51 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %%timeit
df.at['The Shining','runtime']
# Out:
# 165 μs ± 1.25 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
s = df.score

# %%
s.iloc[0]
# Out:
# np.float64(8.4)

# %%
s
# Out:
# name
# The Shining                                       8.4
# The Blue Lagoon                                   5.8
# Star Wars: Episode V - The Empire Strikes Back    8.7
# Airplane!                                         7.7
# Caddyshack                                        7.3
#                                                  ...
# More to Life                                      3.1
# Dream Round                                       4.7
# Saving Mbango                                     5.7
# It's Just Us                                      NaN
# Tee em el                                         5.7
# Name: score, Length: 7666, dtype: float64

# %%
s.loc['In Time']
# Out:
# np.float64(6.7)

# %%
s.at['In Time']
# Out:
# np.float64(6.7)
